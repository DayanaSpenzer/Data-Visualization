# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
#Swarm Plot
import seaborn as sns
import matplotlib.pyplot as plt
data=dataset
sns.swarmplot(x="degree_t",y="degree_p",data=data,hue="gender")
plt.show()

# %%
#swarmplot overlaying boxplot
import seaborn as sns
import matplotlib.pyplot as plt
data=dataset
sns.boxplot(x="degree_t",y="degree_p",data=data,hue="gender")
sns.swarmplot(x="degree_t",y="degree_p",data=data,hue="gender")
plt.show()

# %%
#pointplot
import seaborn as sns
import matplotlib.pyplot as plt
data=dataset
sns.pointplot(x="degree_t",y="degree_p",data=dataset,hue="gender")
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('exercise')
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
#catplot
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
df = sns.load_dataset('exercise')
sns.catplot(x = "time", y = "pulse", hue = "kind", kind = 'violin', col = "diet", data = df);
plt.show()
